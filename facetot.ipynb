# %%
import pandas as pd
from mergestock_tweet import mergeData
from cleanTxt import cleanTxt
from sentfunc import getAnalysis,getPolarity,getSubjectivity
import statsmodels.api as sm
import matplotlib.pyplot as plt
import numpy as np 
csvs = ["/Users/joshuagrajales/Desktop/qac211/project/SM_comm/facebook/facebook1.csv","/Users/joshuagrajales/Desktop/qac211/project/SM_comm/facebook/facebook2.csv","/Users/joshuagrajales/Desktop/qac211/project/SM_comm/facebook/facebook3.csv"]
name = 'facebook'
urls = ['https://query1.finance.yahoo.com/v7/finance/download/FB?period1=1569888000&period2=1572220800&interval=1d&events=history&includeAdjustedClose=true','https://query1.finance.yahoo.com/v7/finance/download/FB?period1=1601510400&period2=1603843200&interval=1d&events=history&includeAdjustedClose=true','https://query1.finance.yahoo.com/v7/finance/download/FB?period1=1638316800&period2=1640908800&interval=1d&events=history&includeAdjustedClose=true']

# %%
def run(csvs,name,urls):
    i = 0 
    first = pd.read_csv(mergeData(csvs[i],name,urls[i]))
    stock1 = list(first['Stock'])
    text1 = list(first['text'])
    date1 = list(first['Date'])

    i = i + 1
    sec = pd.read_csv(mergeData(csvs[i],name,urls[i]))
    stock2 = list(sec['Stock'])
    text2 = list(sec['text'])
    date2 = list(sec['Date'])

    i = i + 1
    thi = pd.read_csv(mergeData(csvs[i],name,urls[i]))
    stock3 = list(thi['Stock'])
    text3 = list(thi['text'])
    date3 = list(thi['Date'])

    all_stock = stock1+stock2+stock3
    all_text = text1+text2+text3
    all_time = date1+date2+date3

    dict = {'d$text': all_text, 'All Stock': all_stock, 'Date': all_time}
    df = pd.DataFrame(dict)
    df['Tweets'] = df['d$text'].apply(cleanTxt)

    # create two new columns (one for subjectivity and polarity)
    df['Subjectivity'] = df['Tweets'].apply(getSubjectivity)
    df['Polarity'] = df['Tweets'].apply(getPolarity)

    # assign Positive, Neutral, or Negative to each tweet
    df['Analysis'] = df['Polarity'].apply(getAnalysis)

    df.head()
    
    mod = sm.OLS(df['All Stock'],sm.add_constant(df['Polarity']), hasconst=True)
    fii = mod.fit()
    p_values =fii.summary2(())

    plt.scatter(df['Polarity'],df['All Stock'])
    plt.title(name)
    plt.grid()
    plt.xlabel("Sentiment Score")
    plt.ylabel("Stock Price")
    x = np.linspace(-1,1,100)
    plt.plot(x,float(fii.params[1])*x+float(fii.params[0]), color = 'black', label = 'Slope: ' + str(int(fii.params[1]))+' Intercept: ' + str(int(fii.params[0])))
    plt.legend()

    print(p_values)

    return df

run(csvs,name,urls)
# Out:
# File stored: /Users/joshuagrajales/Desktop/qac211/project/SM_comm/facebook/f1tot.csv
# File stored: /Users/joshuagrajales/Desktop/qac211/project/SM_comm/facebook/f2tot.csv
# File stored: /Users/joshuagrajales/Desktop/qac211/project/SM_comm/facebook/f3tot.csv
#                  Results: Ordinary least squares
# =================================================================
# Model:              OLS              Adj. R-squared:     0.028
# Dependent Variable: ()               AIC:                654.4446
# Date:               2022-05-01 12:45 BIC:                658.5996
# No. Observations:   59               Log-Likelihood:     -325.22
# Df Model:           1                F-statistic:        2.661
# Df Residuals:       57               Prob (F-statistic): 0.108
# R-squared:          0.045            Scale:              3718.6
# ------------------------------------------------------------------
#            Coef.    Std.Err.     t     P>|t|     [0.025    0.975]
# ------------------------------------------------------------------
# const     270.1139    8.9070  30.3260  0.0000   252.2779  287.9499
# Polarity  -55.5458   34.0509  -1.6313  0.1084  -123.7315   12.6400
# -----------------------------------------------------------------
# 28  A Republican who is voting for Joe sent this t...      0.437500 -0.031250
# 29  The first JobKeeper extension period begins on...      0.166667  0.125000
# 30  People who prefer Twitter over Facebook tend t...      0.666667  0.250000
# 31  Check this page out if you’re ever on Facebook...      0.000000  0.000000
# 32  A Republican who is voting for Joe sent this t...      0.437500 -0.031250
# 33  A Republican who is voting for Joe sent this t...      0.437500 -0.031250
# 34  JYPEntertainment Confirms Date of October 26th...      0.200000  0.200000
# 35  [Schedule] Fantopia2020\n🗓28 Sep 2020\n⏰9am, E...      0.000000  0.000000
# 36  📢 TOMORROW (28 Sep)\n- full Kit content on Mon...      0.510000  0.179091
# 37  Dropping absolute facts in our Facebook suppor...      0.900000  0.200000
# 38  🎁Please join is in wishing a happy new year an...      0.727273  0.468182
# 39  UniArts Metaverse Gallery on Cryptovoxels is o...      0.000000  0.000000
# 40  A little more about myself - my day job is  as...      0.475000  0.215625
# 41  🎁Win the GIFT BOX🎁 on Meta Xmas campaign\n &am...      0.333333  0.250000
# 42  This was posted yesterday in a third strike fa...      0.433333  0.178788
# 43  everyone on twitter hated Don’t Look Up &amp; ...      0.750000 -0.100000
# 44  Beat those January cold snaps with a padded pa...      0.475000  0.300000
# 45  Press briefing regarding the area wildfires wi...      0.000000  0.000000
# 46  NCT127 debuts at 12 on the BillboardHotTrendin...      0.000000  0.000000
# 47   En Facebook, se llama moments between the mom...      0.000000  0.000000
# 48  Weird that almost the exact same photo (just f...      0.493750 -0.062500
# 49  The New Year is a great time to unleash your c...      0.626136  0.459091
# 50  ภารกิจ 31 ธ.ค.\n17:00 น. The Mall Lifestore Ch...      0.500000  0.136364
# 51  Join Us Live For Day 3\nMy House Shall Be A Ho...      0.633333  0.290909
# 52  GulfxFeed: Gulf Kanawut Traipipattanapong and ...      0.050000  0.000000
# 53  🔥 Join TheCryptoYou Whitelist for Gift Box dur...      0.708333  0.083333
# 54  IF THERE IS ONE TWEET YOU DO TODAY PLEASE LET ...      0.360000 -0.080000
# 55  I turned 32 today…. I’m sick, and still in Fac...      0.428571 -0.407143
# 56  คอนเสิร์ต SMTOWN LIVE 2022 ดูฟรี\nสามารถดูได้ห...      0.355556  0.102020
# 57  Epic fail. The Texas Republican mistook the We...      0.262500 -0.087500
# 58   Maybe ask on Facebook. Seems there are more d...      0.500000  0.500000
#
#     Analysis
# 0    Neutral
# 1    Neutral
# 2   Positive
# 3   Negative
# 4    Neutral
# 5   Positive
# 6   Positive
# 7   Positive
# 8   Positive
# 9    Neutral
# 10  Positive
# 11   Neutral
# 12  Positive
# 13  Negative
# 14  Positive
# 15  Positive
# 16  Negative
# 17  Positive
# 18  Positive
# 19  Negative
# 20   Neutral
# 21   Neutral
# 22  Negative
# 23  Positive
# 24  Negative
# 25   Neutral
# 26  Negative
# 27   Neutral
# 28  Negative
# 29  Positive
# 30  Positive
# 31   Neutral
# 32  Negative
# 33  Negative
# 34  Positive
# 35   Neutral
# 36  Positive
# 37  Positive
# 38  Positive
# 39   Neutral
# 40  Positive
# 41  Positive
# 42  Positive
# 43  Negative
# 44  Positive
# 45   Neutral
# 46   Neutral
# 47   Neutral
# 48  Negative
# 49  Positive
# 50  Positive
# 51  Positive
# 52   Neutral
# 53  Positive
# 54  Negative
# 55  Negative
# 56  Positive
# 57  Negative
# 58  Positive
